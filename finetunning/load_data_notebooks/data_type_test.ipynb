# %%
import pandas as pd

# %%
val = pd.read_csv('/opt/ml/projects/tunning_data/validation_v1.csv')

# %%
val = val.rename(columns = {'right_ans':'sent_a', 'student_ans':'sent_b', 'Label':'labels'}).drop(columns='Unnamed: 0')

# %%
val
# Out:
#                                                 sent_a  \
# 0    제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# 1    제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# 2    제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# 3    제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# 4    제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# ..                                                 ...
# 105  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
# 106  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
# 107  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
# 108  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
# 109  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
#
#                                                 sent_b  labels
# 0    제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...       1
# 1    제품의 가격이 높아지고, 품질이 나빠진다. 또 제품의 다양성이 감소하고, 소비자들은...       0
# 2    제품의 가격이 높아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...       0
# ...

# %%
val.to_csv('/opt/ml/projects/tunning_data/validation_v1.csv')

# %%
val = pd.read_csv('/opt/ml/projects/tunning_data/validation_v1.csv')

# %%
val
# Out:
#      Unnamed: 0                                             sent_a  \
# 0             0  제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# 1             1  제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# 2             2  제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# 3             3  제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# 4             4  제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...
# ..          ...                                                ...
# 105         105  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
# 106         106  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
# 107         107  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
# 108         108  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
# 109         109  금속은 열전도율이 높은 재질이기 때문에 뜨거운 물에서 차가운 금속 국자로 열이 이동...
#
#                                                 sent_b  labels
# 0    제품의 가격이 낮아지고, 품질이 좋아진다. 또 제품의 다양성이 증가하고, 소비자들은...       1
# ...
